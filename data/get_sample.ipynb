# %%
import pandas as pd

# %%
data_path = "raw/project_schedule_data.csv"  # Adjust path if necessary
df = pd.read_csv(data_path)

# %%
df.head(15)
# Out:
#    Task ID  Team Size  Resource Availability  Complexity  Priority  Risk  \
# 0    T0001          7                   0.74           3         9   0.5
# 1    T0002          4                   0.78           5         5   0.7
# 2    T0003         15                   0.84           1         1   0.1
# 3    T0004          4                   0.82           4         5   0.9
# 4    T0005          9                   0.97           2         5   0.3
# 5    T0006          5                   0.64           5         4   0.9
# 6    T0007         19                   0.78           5         2   0.7
# 7    T0008         16                   0.98           1         2   0.5
# 8    T0009         10                   0.71           1         5   0.1
# 9    T0010          4                   0.95           1         6   0.5
# 10   T0011         11                   0.94           1         9   0.5
# 11   T0012          6                   0.59           4         5   0.3
# ...

# %%
sample = df[0:7]
sample
# Out:
#   Task ID  Team Size  Resource Availability  Complexity  Priority  Risk  \
# 0   T0001          7                   0.74           3         9   0.5
# 1   T0002          4                   0.78           5         5   0.7
# 2   T0003         15                   0.84           1         1   0.1
# 3   T0004          4                   0.82           4         5   0.9
# 4   T0005          9                   0.97           2         5   0.3
# 5   T0006          5                   0.64           5         4   0.9
# 6   T0007         19                   0.78           5         2   0.7
#
#   Environment                 Dependencies  Task Duration (Days)  \
# 0      Arctic                           []                    42
# 1      Arctic                    ['T0001']                    59
# 2      Desert           ['T0002', 'T0001']                    18
# 3     Onshore  ['T0002', 'T0001', 'T0003']                    54
# ...

# %%
sample.to_csv('Sample1.csv', index=False)
